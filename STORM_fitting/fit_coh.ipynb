# %%
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import xarray as xr

import drdmannturb as drdmt

# %% [markdown]
# # CREATE DATASET IN DRDMANNTURB

# %%
domain = torch.logspace(-1, 3, 40)

L = 70
Gamma = 3.7
sigma = 0.04
Uref = 21

# NOTE: Below is obtained from the LES data... we used the 31st of 60
#       heights that we were given, so this is height[30]
zref = 148.56202535609793

# %%
spectra_file = Path("data_cleaned/log_downsampled_6component_spectra.dat")
CustomData = torch.tensor(np.genfromtxt(spectra_file, skip_header=1, delimiter = ","))

f = CustomData[:, 0]
k1_data_pts = 2 * torch.pi * f / Uref

gen = drdmt.OnePointSpectraDataGenerator(
    zref = zref,
    data_points = k1_data_pts,
    data_type = drdmt.DataType.CUSTOM,
    spectra_file = spectra_file,
    k1_data_points = k1_data_pts.data.cpu().numpy(),
)

gen.Data
# Out:
# ([(tensor(0.0010, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0015, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0020, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0025, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0030, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0035, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0040, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0045, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0050, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0055, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0060, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0065, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0070, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0075, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0080, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0085, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0090, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0095, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0100, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0105, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0110, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0115, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0120, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0125, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0135, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0140, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0145, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0150, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0160, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0165, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0175, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0185, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0189, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0199, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0209, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0219, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0229, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0239, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0254, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0264, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0279, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0289, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0304, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0319, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0334, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0349, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0364, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0384, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0399, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0419, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0439, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0459, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0484, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0504, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0529, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0554, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0578, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0608, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0633, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0668, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0698, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0728, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0763, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0803, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0838, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0878, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0918, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.0962, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1007, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1057, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1107, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1157, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1212, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1272, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1331, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1391, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1461, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1531, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1601, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1676, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1755, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1840, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.1925, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.2015, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.2109, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.2209, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.2314, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.2424, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.2538, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.2658, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.2788, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.2917, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.3057, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.3201, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.3351, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.3511, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.3675, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.3850, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.4029, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.4219, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.4418, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.4628, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.4847, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.5076, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.5316, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.5570, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.5829, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.6109, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.6398, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.6697, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.7016, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.7345, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.7694, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.8058, dtype=torch.float64), 148.56202535609793),
#   (tensor(0.8437, dtype=torch.float64), 148.56202535609793)],
#  tensor([[[54.6786, 38.6387, -5.1184],
#           [ 0.0000, 48.3989,  3.2222],
#           [ 0.0000,  0.0000,  5.3486]],
#
#          [[96.2775, 25.3792, -5.5605],
#           [ 0.0000, 93.1370,  4.8663],
#           [ 0.0000,  0.0000,  5.1629]],
#
#          [[76.7578, 20.1212, -7.0563],
#           [ 0.0000, 67.5093,  6.9514],
#           [ 0.0000,  0.0000, 10.8729]],
#
#          ...,
#
#          [[ 6.2144,  4.7309, -3.0188],
#           [ 0.0000, 12.7233,  4.2953],
#           [ 0.0000,  0.0000,  5.5434]],
#
#          [[ 7.2444,  3.3699, -2.4030],
#           [ 0.0000,  8.0910,  2.4673],
#           [ 0.0000,  0.0000,  5.3358]],
#
#          [[ 4.3382,  2.9156, -1.4874],
#           [ 0.0000,  6.2511,  2.1271],
#           [ 0.0000,  0.0000,  3.6935]]]))

# %% [markdown]
# # FIT 6 component spectra

# %%
domain = torch.logspace(-1, 3, 40)

L = 70
Gamma = 3.7
sigma = 0.04
Uref = 21

# NOTE: Below is obtained from the LES data... we used the 31st of 60
#       heights that we were given, so this is height[30]
zref = 148.56202535609793
device = "cpu"

pb = drdmt.CalibrationProblem(
    nn_params=drdmt.NNParameters(
        nlayers=3, hidden_layer_sizes=[10, 10, 10], activations=[nn.ReLU(), nn.ReLU(), nn.ReLU()]
    ),
    prob_params=drdmt.ProblemParameters(
        data_type=drdmt.DataType.CUSTOM, 
        tol=1e-9,
        nepochs=5,
        learn_nu=True,
        learning_rate=0.3, # Default is 0.1
        # init_with_noise=True,
        noise_magnitude=0.1 # Default is 0.01
    ),
    loss_params=drdmt.LossParameters(
        alpha_pen1=10.0,
        alpha_pen2=10.0,
        beta_reg=1e-1
    ),
    phys_params=drdmt.PhysicalParameters(
        L=L,
        Gamma=Gamma,
        sigma=sigma,
        domain=domain,
        Uref=Uref,
        zref=zref,
    ),
    logging_directory="runs/custom_data",
    device=device,
)

# %%
optimal_params = pb.calibrate(data=gen.Data)
# Out:
# ========================================
# Initial loss: nan
# ========================================
#   0%|          | 0/5 [00:58<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 optimal_params = pb.calibrate(data=gen.Data)
#
# File ~/Work/DRDMannTurb/drdmannturb/spectra_fitting/calibration.py:480, in CalibrationProblem.calibrate(self, data, tb_comment, optimizer_class)
#     477 scheduler.step()
#     479 if not (torch.isfinite(self.loss)):
# --> 480     raise RuntimeError("Loss is not a finite value, check initialization and learning hyperparameters.")
#     482 if self.loss.item() < tol:
#     483     print(f"Spectra Fitting Concluded with loss below tolerance. Final loss: {self.loss.item()}")
#
# RuntimeError: Loss is not a finite value, check initialization and learning hyperparameters.

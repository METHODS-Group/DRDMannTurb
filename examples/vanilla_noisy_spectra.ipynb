# %%
import sys
# sys.path.append('../')
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

import numpy as np
import matplotlib.pyplot as plt
plt.rc('text',usetex=True)
plt.rc('font',family='serif')

from pylab import *
import pickle
from math import log
from torch.nn import parameter

from fracturbulence.common import *
from fracturbulence.Calibration import CalibrationProblem
from fracturbulence.DataGenerator import OnePointSpectraDataGenerator

from pathlib import Path

savedir = Path().resolve() / "data" / "results"

# %%
import fracturbulence as ft

# %%
spectra = np.genfromtxt("../script/Spectra.dat", delimiter=',')

# %%
####################################
### Configuration
####################################

config = {
    'type_EddyLifetime' :   'tauNet',  ### 'const', TwoThird', 'Mann', 'tauNet'
    'type_PowerSpectra' :   'RDT', ### 'RDT', 'zetaNet', 'C3Net', 'Corrector'
    'nlayers'           :   2,
    'hidden_layer_size' :   10,
    'learn_nu'          :   True, ### NOTE: Experiment 1: False, Experiment 2: True
    'plt_tau'           :   True,
    'tol'               :   1.e-3, ### not important
    'lr'                :   1,     ### learning rate
    'penalty'           :   1,  #originally: 1.e-1,
    'regularization'    :   1.e-2,
    'nepochs'           :   2,
    'curves'            :   [0,1,2,3],
    'data_type'         :   'Custom', ### 'Kaimal', 'SimiuScanlan', 'SimiuYeo', 'iso'
    'spectra_file'       :   '../script/Spectra.dat',
    'Uref'              :   10, # m/s
    'zref'              :   1, #m
    'domain'            :   torch.logspace(-2, 2, 20), ### NOTE: Experiment 1: np.logspace(-1, 2, 20), Experiment 2: np.logspace(-2, 2, 40)
    'noisy_data'        :   7.e-2, # 0*3.e-1, ### level of the data noise  ### NOTE: Experiment 1: zero, Experiment 2: non-zero
    'output_folder'     :   savedir,
    'input_folder'      :   '../script/'
}
pb = CalibrationProblem(**config)
# Out:
# ['relu', 'relu']
# /home/ai/miniconda3/envs/fracturbulence/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
####################################
#Calculating turbulence parameters according to IEC standards
# we assume a hub height z=150m corresponding to the IEA 15MW wind turbine hub height
zref=config['zref']; # Hub height in meters
Uref=config['Uref']; # Average Hub height velocity in m/s
Iref = 0.14
sigma1=Iref*(0.75*Uref+5.6)
Lambda1=42; # Longitudinal turbulence scale parameter at hub height


#Mann model parameters
#Gamma = 3.9
#sigma = 0.55*sigma1
#L=0.8*Lambda1;


z0=0.01
ustar=0.41*Uref/log(zref/z0)

L     = 14.09
Gamma = 3.9
sigma = 0.15174254

print(L,Gamma,sigma)

parameters = pb.parameters
parameters[:3] = [log(L), log(Gamma), log(sigma)] #All of these parameters are positive 
#so we can train the NN for the log of these parameters. 
pb.parameters = parameters[:len(pb.parameters)]

k1_data_pts = config['domain'] #np.logspace(-1, 2, 20)


if(config['data_type']=='Custom'):
    if config['spectra_file'] is not None:
        spectra_file=config['spectra_file']
        print('Reading file' + spectra_file + '\n')
        CustomData=np.genfromtxt(spectra_file,skip_header=1,delimiter=',')
        f=CustomData[:,0]
        k1_data_pts=2*np.pi*f/Uref

DataPoints  = [ (k1, 1) for k1 in k1_data_pts ]
Data = OnePointSpectraDataGenerator(DataPoints=DataPoints, **config).Data

### Data perturbation
data_noise_magnitude = config['noisy_data']
if data_noise_magnitude:
    Data[1][:] *= np.exp(np.random.normal(loc=0, scale=data_noise_magnitude, size=Data[1].shape))

DataValues = Data[1]
# Out:
# 14.09 3.9 0.15174254
# Reading file../script/Spectra.dat
#
# Reading file ../script/Spectra.dat
#
# DataValues is on -1

# %%
type(k1_data_pts)
# Out:
# numpy.ndarray

# %%
IECtau=MannEddyLifetime(k1_data_pts*L)
plt.figure(1)
plt.loglog(k1_data_pts*L,IECtau,'k')
#plt.xlim(0.1,60)
plt.ylabel(r'$\tau(k)$ (aribitrary units)',fontsize=18)
plt.xlabel(r'$(kL)$',fontsize=18)
plt.show()
#plt.savefig('tau.png')

# %%
plt.rc('text',usetex=True)
plt.rc('font',family='serif')


kF = pb.eval(k1_data_pts)
plt.figure(1,figsize=(10,10))
clr=['black','blue','red']
plt.figure(1)
for i in range(3):
    plt.plot(k1_data_pts, kF[i], '-', color=clr[i], label=r'$F_{0:d}$ model'.format(i+1))
    plt.plot(k1_data_pts, DataValues[:,i,i], '--',color=clr[i],label=r'$F_{0:d}$ data'.format(i+1) )#, label=r'$F_{0:d}$ data'.format(i+1))
plt.plot(k1_data_pts, -kF[3], '-m', label=r'-$F_{13}$ model')
plt.plot(k1_data_pts, -DataValues[:,0,2], '--m', label=r'$-F_{13}$ data')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$k_1$',fontsize=22)
#plt.xlim(0.01,2)
#plt.ylim(0.00001,0.1)
plt.ylabel(r'$k_1 F(k_1)/u_\ast^2$',fontsize=22)
plt.legend(loc='lower left',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid(which='both')
plt.title("Initial Guess")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 5
#       1 plt.rc('text',usetex=True)
#       2 plt.rc('font',family='serif')
# ----> 5 kF = pb.eval(k1_data_pts)
#       6 plt.figure(1,figsize=(10,10))
#       7 clr=['black','blue','red']
#
# File ~/Documents/wind/WindGenerator/fracturbulence/Calibration.py:116, in CalibrationProblem.eval(self, k1)
#     115 def eval(self, k1):
# --> 116     Input = self.format_input(k1)
#     117     with torch.no_grad():
#     118         Output = self.OPS(Input)
#
# File ~/Documents/wind/WindGenerator/fracturbulence/Calibration.py:141, in CalibrationProblem.format_input(self, k1)
#     128 def format_input(self, k1: torch.Tensor):
#     129     """Wrapper around clone and cast k1 to torch.float64
#     130
#     131     Parameters
#    (...)
#     139         Tensor of float64
#     140     """
# --> 141     formatted_k1 = k1.clone().detach()
#     142     formatted_k1.requires_grad = k1.requires_grad
#     144     return formatted_k1.to(torch.float64)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'clone'

# %%
opt_params = pb.calibrate(Data=Data, **config)
# Out:
# Callibrating MannNet...
# Initial loss:  1.653980208845049
#
# =================================
# -> Epoch 0
# =================================
#
# pen =  0.0031851430368418023
# reg =  0.0004349448789579711
# loss  =  1.6576002967608487
# -> nu =  -0.3333333432674408
# pen =  0.0042178706065537875
# reg =  0.0004347339726847125
# loss  =  0.4874780514961895
# -> nu =  -0.33185198266569016
# pen =  0.003530876774041587
# reg =  0.0004350022437876562
# loss  =  0.41423943583895545
# -> nu =  -0.3307235963231372
# pen =  0.00260989545621355
# reg =  0.000435395262176864
# loss  =  0.38355182707981406
# -> nu =  -0.32856173803436906
# pen =  0.00026780064028461754
# reg =  0.00043691678004498317
# loss  =  0.31506315512975275
# -> nu =  -0.31966984178060476
# pen =  1.4209862070657512e-05
# reg =  0.0004380047551019008
# loss  =  0.28369212446494674
# -> nu =  -0.3111268602763875
# pen =  4.614542895654577e-05
# reg =  0.0004383273851653071
# loss  =  0.27864968574619525
# -> nu =  -0.3058344712115175
# pen =  5.204945741792665e-05
# reg =  0.00043834910169963064
# loss  =  0.2783836811598689
# -> nu =  -0.3041957668578479
# pen =  5.715061211985367e-05
# reg =  0.00043833322843200357
# loss  =  0.2779761489247191
# -> nu =  -0.3009601418156138
# pen =  6.577591948699365e-05
# reg =  0.00043823861846639683
# loss  =  0.2769056200709302
# -> nu =  -0.29123871788042127
# pen =  7.151529463827865e-05
# reg =  0.0004381082252578528
# loss  =  0.2748807959912397
# -> nu =  -0.27125092487875224
# pen =  7.511710187286554e-05
# reg =  0.0004384136305291484
# loss  =  0.27156548033828665
# -> nu =  -0.23444562205304434
# pen =  7.521020446833596e-05
# reg =  0.00044821504573437984
# loss  =  0.2674115800408379
# -> nu =  -0.14696601442326598
# pen =  0.00016135402942602021
# reg =  0.0004635006645433436
# loss  =  0.26548850108978156
# -> nu =  -0.06884868177151802
# pen =  0.00018988984172101342
# reg =  0.0004754194014937215
# loss  =  0.2645363011457485
# -> nu =  -0.026760572824894933
# pen =  0.00018807858452776712
# reg =  0.000575078349465724
# loss  =  0.2607444742449973
# -> nu =  0.2086366427093482
# pen =  0.00012488071333387898
# reg =  0.0006464998446015731
# loss  =  0.2581832432204336
# -> nu =  0.3274435056968964
# pen =  0.00014256165569151717
# reg =  0.0010565326041066885
# loss  =  0.24939468608867602
# -> nu =  0.8116979014301182
# pen =  1.780981040034551e-05
# reg =  0.0014365372484722988
# loss  =  0.24915439445426113
# -> nu =  1.1132202652176768
# pen =  4.154547195599941e-06
# reg =  0.0015068167887724354
# loss  =  0.24591864997414004
# -> nu =  1.1657317200778212
# pen =  7.505493054961962e-07
# reg =  0.0016953179031145072
# loss  =  0.23918386931815677
# -> nu =  1.3038565038991958
# grad =  [-1.77794279e-02 -4.62344714e-02  1.97153981e-02 -4.30865886e-05
#  -5.31420211e-05  1.14949420e-07 -4.72454583e-06 -6.57196847e-05
#  -3.79019084e-06 -5.06069492e-04 -2.08669835e-04 -5.05043010e-04
#  -6.36848342e-03 -6.06643537e-03 -2.03359103e-03  1.48705527e-02
#   1.31157509e-02  4.98535103e-03  1.76890727e-04  3.28290195e-04
#  -9.01250141e-04  8.60624080e-06 -2.50723452e-04 -1.47387808e-03
#  -1.12360185e-05 -2.62212113e-05 -2.15438521e-05 -5.90127055e-05
#  -5.13216837e-06 -6.60418641e-05  1.84401496e-03  4.05512980e-04
#  -1.66227431e-04 -3.14626251e-05 -3.40677808e-05 -2.55040419e-05
#   5.73295336e-03  3.24242341e-03 -5.87058191e-04 -2.51316829e-04
#  -3.01324212e-05  2.90114481e-05  1.97643026e-04 -1.43548780e-05
#  -1.36255216e-05 -8.09932946e-05  3.62968720e-04 -2.32775022e-04
#  -5.61040649e-04 -2.10891058e-04  6.55486506e-06 -3.68437988e-05
#  -5.33788988e-05  2.06682950e-05  2.75869699e-05  7.16283626e-06
#  -1.34060708e-04 -1.30870567e-04 -2.59999804e-04 -6.87906605e-05
#  -2.83819922e-05 -2.96363142e-05  1.17741023e-05  2.30765750e-05
#  -3.42784643e-05 -9.20076547e-05  9.74602943e-03  5.08773506e-03
#  -5.91135427e-04 -1.94921980e-04  1.12901937e-05 -4.94876710e-06
#   3.05821280e-04 -6.52881093e-06 -3.12371571e-05 -1.93095359e-05
#  -2.55615087e-05 -4.25004724e-05 -3.18576304e-05 -8.82573788e-06
#  -2.92290873e-05 -4.51771225e-06 -4.27487382e-05 -8.38017813e-06
#  -3.40476340e-05  9.30252338e-06 -4.23258403e-03 -3.48771349e-04
#  -1.28028191e-07 -1.09060998e-05  1.44867835e-05  8.01793078e-06
#  -2.39403142e-05 -2.03784134e-05  2.56921090e-05 -4.04966014e-05
#   1.46917077e-03  8.59435592e-04 -2.99087537e-04 -1.39044526e-04
#  -3.56601403e-05  5.79895021e-06  9.63663806e-05 -2.69621863e-05
#   3.62350873e-05  7.15461045e-06 -3.21272719e-03 -1.19962586e-03
#   1.01322144e-04  4.45657284e-05 -1.99613013e-05 -2.37044217e-05
#  -7.95926593e-05  1.87363096e-05  2.55144698e-05 -1.79324454e-05
#  -3.68682822e-05 -1.04029883e-05 -3.61619869e-05  2.53329942e-06
#  -2.28338109e-05 -5.54926171e-06 -3.09307014e-05  2.40556937e-05
#   1.47308423e-06 -1.96108762e-06  3.00750289e-06  4.29718835e-05
#  -3.38079196e-05  9.49726280e-06 -4.82943219e-06 -2.97745433e-06
#   4.29564163e-06  4.21177138e-04 -1.38430147e-04  7.16672537e-04
#   1.46109437e-03 -2.44730879e-05  9.41262265e-05  1.26576725e-03
#   4.58640127e-03  1.94771617e-05 -2.96729744e-05  5.03426471e-04
#   1.73475946e-04  6.28651731e-04  1.08148387e-03 -5.97471717e-05
#   1.43862529e-04  8.54162375e-04  4.24788748e-03 -8.02232307e-07
#  -7.13935120e-06 -3.17410190e-04 -7.03636743e-04  6.11582102e-05
#   6.37588596e-04 -4.75475993e-05  4.62889429e-07  6.75776113e-04
#   2.28212278e-03  2.35975916e-05  3.45883951e-05 -6.10083488e-04]
# ---------------------------------
#
# Optimal NN parameters = [2.579270886454459, 0.8515982451725459, -0.696184809402177, -0.3446927084702277, -0.42513616914433666, 0.0009195953627741732, -0.03779636663464752, -0.5257574779075969, -0.03032152669886982, -0.1677516313707973, -0.27324729005541565, 0.3573134195757427, 0.7799353354231711, 0.38877936358585286, -0.23948458068186995, 0.33173177949561866, -0.393028495010996, 1.6146356862152205, -0.17536379065096092, -0.7467485373062615, 1.3257486390771145, -0.048716653999911194, -0.4377414612292915, 0.6246761611479389, 0.014769181839489127, -0.20833885082808284, -0.16757766480424924, -0.4721016439851273, -0.04105734697186245, -0.5283349131419681, 0.21471144874530937, -0.4598599559317019, 0.12981706053052539, -0.25170100050437627, -0.2725422463212409, 0.5303226843703444, -0.47077819522398795, 0.9709828255792263, 0.9267317670671626, 0.6371916291721624, -0.24318659803779413, 0.2320915849625044, 0.18677765626750537, -0.11483902362099777, -0.10900417241696783, -0.02451555420856217, -0.701776689225533, 0.7175864070941035, 0.3035851981026029, 0.6168073235656495, 0.05243892045902082, -0.294750390744917, 0.1289827192677903, 0.16534635999871247, 0.220695759521813, 0.4249359096036733, -0.3009999654039558, 0.8109958697456972, 0.7476208984624754, 0.7814470347021999, -0.22732564650908765, -0.23709051361289946, 0.05516453482855466, 0.1846126000073669, -0.27422771463242823, -0.03166210073430011, -0.26790706728880515, 0.90797505043507, 0.6608013788347542, 0.9828073700192747, 0.08710085712447148, -0.03959013683554622, 0.3876310483699535, -0.05223048741205232, -0.2498972568515582, -0.15447628696419732, -0.20449206943650278, -0.34000377899351053, -0.2548610434504408, -0.07060590304780512, -0.23383269862961717, -0.03614169796898623, -0.3419899057953445, -0.06704142506015826, -0.27238107227080177, 0.0744201870253919, 0.03296124675215345, -0.12652215500424985, -0.0010242255246548128, -0.08724879855933516, 0.11589426780868448, 0.06414344621034146, -0.18859895746852082, -0.1630273073777175, 0.2055368720634329, 0.055764676345041675, -0.19015154017575506, 0.7028698784666028, 0.5219096231020989, 0.26149647890485295, -0.28613879714968393, 0.04639160170034379, 0.35648553719392284, -0.2156974902266262, 0.289880698036611, -0.07341615651400353, 0.2711154275446132, 0.20117450491254696, -0.23789070759392628, -0.1384071799329899, -0.15908832862573194, -0.1896353735067617, -0.2179739435826841, 0.14989047648050752, 0.20411575815025357, -0.14345956280485697, -0.29494625790402357, -0.08322390630354576, -0.2892958949848162, 0.020266395399389243, -0.18267048723374618, -0.04439409368778169, -0.2474456111509385, 0.19244554938362235, 0.01178467382855357, -0.015687203880915934, -0.14191728206523144, 0.13071057832975225, -0.27712150619197046, 0.07573545561100244, -0.03863545748500055, -0.023819634652583483, 0.03436513304850138, 0.30753542407027906, 0.4346004815995323, -0.1875110904060844, 0.3630467335915536, -0.19578470305835088, -0.21912697754871316, -0.03857702685165777, -0.05866444958103859, 0.15581729368377645, -0.2412974685763522, -0.2605054385867601, 0.31046936121642327, -0.6042518741595967, 0.14029733705043632, -0.47797737342833696, -0.3710540538795752, -0.32300914025568567, -0.06946059908502526, -0.006417858456414423, -0.060392131394963806, 1.1867315922802537, 1.045472105476, 0.6037804141118693, 1.1800296631080722, -0.380380794739565, -0.04138262820179847, 0.6319386918609007, -0.2553819482163588, 0.18878073263953346, 0.26297865999541675, 1.3038565038991958]
#
# =================================
#
#
# =================================
# -> Epoch 1
# =================================
#
# pen =  7.505493054961962e-07
# reg =  0.0016953179031145072
# loss  =  0.23918386931815677
# -> nu =  1.3038565038991958
# pen =  1.0571695874234491e-05
# reg =  0.001909511079629129
# loss  =  0.23560374573606063
# -> nu =  1.4373367856551655
# pen =  0.00027935262144866067
# reg =  0.003004741881610197
# loss  =  0.22848851316835062
# -> nu =  1.9965412815494796
# pen =  0.00030648505790005476
# reg =  0.0035331278701032447
# loss  =  0.22558717961687869
# -> nu =  2.2180880516615824
# pen =  0.001166440534363964
# reg =  0.006020897637295701
# loss  =  0.2167292326333341
# -> nu =  3.063190242866267
# pen =  0.0006259889838851404
# reg =  0.005505611608394799
# loss  =  0.21772744033117933
# -> nu =  2.9072686926986493
# pen =  0.0009465176605315858
# reg =  0.005877382607767312
# loss  =  0.21691904524592714
# -> nu =  3.020529609607163
# pen =  0.0010091829239442735
# reg =  0.005965034900899557
# loss  =  0.21673171467465263
# -> nu =  3.046652009409479
# pen =  0.0010004188301302019
# reg =  0.005991418462401306
# loss  =  0.21664770820356388
# -> nu =  3.054473469483639
# pen =  4.6786136512733615e-05
# reg =  0.00860629367010655
# loss  =  0.22564623145988497
# -> nu =  3.7872287651777756
# pen =  0.0059216937362688215
# reg =  0.007162460419164521
# loss  =  0.2145998939733128
# -> nu =  3.4001856552050755
# pen =  0.00037780013597036444
# reg =  0.0076035109108936304
# loss  =  0.21151278842137206
# -> nu =  3.522480221814809
# pen =  0.0009426998864886551
# reg =  0.007346894280716954
# loss  =  0.21043114896360163
# -> nu =  3.451799133891442
# pen =  0.00013660394512726403
# reg =  0.012865066189944747
# loss  =  0.5639439326294889
# -> nu =  4.713513647664935
# pen =  0.0005090107977687755
# reg =  0.0074536833716416315
# loss  =  0.2105767390340151
# -> nu =  3.4804204477824037
# pen =  0.0007306430364356293
# reg =  0.007382705220202373
# loss  =  0.21038608367690442
# -> nu =  3.4614226112363435
# pen =  0.000796505751717276
# reg =  0.007370551975007209
# loss  =  0.21039249805975282
# -> nu =  3.4581595742471376
# pen =  0.0007454368299684229
# reg =  0.007378490675761747
# loss  =  0.21037994095192072
# -> nu =  3.460291381314714
# pen =  7.036750373754533e-05
# reg =  0.00525065968724097
# loss  =  0.22273709909507713
# -> nu =  2.821948326564306
# pen =  0.02181936435602462
# reg =  0.006479187571852585
# loss  =  0.22449747530629185
# -> nu =  3.204609888618653
# pen =  0.0007523917962279299
# reg =  0.007373558224184318
# loss  =  0.21032848570043694
# -> nu =  3.458936130456169
# pen =  0.000953467041187745
# reg =  0.0072813233230493634
# loss  =  0.20943803474534287
# -> nu =  3.4335035062724173
# pen =  0.0009613514998430784
# reg =  0.007277228824473195
# loss  =  0.20939754073323824
# -> nu =  3.4323705105392417
# pen =  0.0013155885006877032
# reg =  0.0071951808319027834
# loss  =  0.2087858073701735
# -> nu =  3.409594448347183
# pen =  0.0002001585496623372
# reg =  0.005489079521366238
# loss  =  0.20898622845394224
# -> nu =  2.8931592002465027
# pen =  0.008643903725410764
# reg =  0.006197706849209821
# loss  =  0.2109168311457193
# -> nu =  3.1170715272510714
# pen =  0.0013148851453001346
# reg =  0.007182257298821047
# loss  =  0.2086599482966661
# -> nu =  3.4059509667194052
# pen =  0.00146789489084597
# reg =  0.007080237036712729
# loss  =  0.20783722970539706
# -> nu =  3.3770630227725715
# grad =  [-7.94088754e-02  1.87190029e-02  3.86706464e-02 -3.90559123e-05
#  -4.81706764e-05  1.04196100e-07 -4.28257269e-06 -5.95717212e-05
#  -3.43562500e-06  7.19536532e-03  1.47056045e-02  9.76600429e-03
#  -1.14543436e-02 -1.92036854e-02 -1.58048082e-02  1.78706276e-02
#   3.74203504e-02  2.46390995e-02  6.39048257e-04  6.77579331e-04
#   1.24046203e-03 -6.03700457e-05 -1.27844017e-04  1.51785714e-04
#   1.75064137e-06 -2.35897184e-05 -1.89825555e-05 -5.34921683e-05
#  -4.65206284e-06 -5.98637613e-05  1.25919282e-03  2.32065559e-04
#   4.63919851e-04 -2.85193506e-05 -3.08807985e-05 -1.77334251e-04
#  -4.54646648e-03 -2.51633998e-03  1.63585498e-04  2.01993935e-04
#  -2.75564936e-05  2.62974770e-05  1.41992528e-04 -1.30120038e-05
#  -1.23508774e-05  6.47969493e-05  1.76076318e-04  4.62991432e-04
#   6.78160845e-05  1.57543730e-04  5.94097635e-06 -3.33971248e-05
#   4.73100112e-05  1.87348115e-05  2.50062563e-05  1.50070258e-03
#   4.36437958e-02  1.74579240e-02  1.35612630e-04  2.21364180e-04
#  -2.57638801e-05 -2.68638879e-05  1.39173440e-04  2.09178011e-05
#  -3.10717729e-05 -2.71857414e-04 -4.08139305e-03 -2.60644179e-03
#   1.63094565e-04  2.25976053e-04  9.86516437e-06 -4.48581845e-06
#   1.64557392e-05 -5.91805189e-06 -2.83149747e-05 -1.75016263e-05
#  -8.25576997e-05 -4.83549845e-05 -1.08452930e-04 -2.43822593e-05
#  -2.64850014e-05 -4.09508803e-06 -4.72228662e-05 -7.59622687e-06
#  -3.08625364e-05 -1.78204709e-03 -3.37981842e-02 -2.01751197e-02
#  -2.10297147e-05 -1.59001470e-05  1.33488198e-05  7.26786713e-06
#   5.87891131e-05 -1.84720479e-05  2.32886564e-05 -1.63803990e-05
#  -1.23976544e-04 -3.00129520e-04  9.00211476e-05  1.07617881e-04
#  -3.24252354e-05  5.25646839e-06  1.87255459e-04 -2.44399201e-05
#   3.28453571e-05 -1.51590713e-03 -1.32586751e-02 -1.65338712e-02
#  -2.19527225e-05 -1.30647664e-05 -1.78442913e-05 -2.14869138e-05
#   2.55683256e-05  1.69835600e-05  2.31276350e-05 -1.62548959e-05
#  -3.34193178e-05 -9.42980661e-06 -3.27790952e-05  2.29631362e-06
#  -2.06977471e-05 -5.03013782e-06 -2.80371874e-05  2.18053249e-05
#   1.33527973e-06 -1.54191902e-06 -1.60580916e-05  1.52474977e-05
#  -3.11199146e-05  8.97612836e-06 -4.37764711e-06 -2.69891860e-06
#   4.02518992e-06  7.71687162e-05  1.16968958e-04 -1.45606559e-03
#   8.18289855e-05 -1.02277284e-04  6.62482289e-03  1.12938109e-04
#   2.26811695e-02  1.76551067e-05 -2.73351039e-05  1.82160696e-05
#   5.44206365e-05 -9.70509052e-04  4.43624038e-05 -1.46710398e-04
#   4.51691776e-03  5.39630049e-05  1.09745553e-02 -7.27184854e-07
#  -6.83964776e-06  9.76805282e-05  2.44390331e-04  3.47832352e-04
#   1.84845789e-04 -7.08939617e-05 -8.57811282e-03 -1.85085432e-04
#  -1.37833877e-02  2.13900774e-05  2.98184368e-05 -1.25698496e-03]
# ---------------------------------
#
# Optimal NN parameters = [2.6822995333924746, 0.7309544229240039, -0.5590266114346084, -0.31244729805541493, -0.3853654112507896, 0.000833568797212124, -0.034260581500892034, -0.47657376952853875, -0.02748499999324846, -0.0363264975209832, -0.23159815175935428, 0.4511230593853443, 1.4678518605809232, 1.2432124861797869, -0.11014312120809225, -0.0833781009021522, -1.435899237820142, 3.2289515343956428, -0.8161398746274009, -2.347279241738609, 2.8787706791677325, -0.5199992206562976, -1.3176010793641548, 1.0941457447121263, 0.014849414740581301, -0.1887962326658697, -0.1518545778441983, -0.42793734664512967, -0.03721650273257845, -0.478910090126866, 0.09394586980981329, -0.6158032849514616, 0.3246091269158366, -0.2281548045343399, -0.2470463876272573, 0.8726302627637851, -1.181379673089081, 1.95810805479316, 1.8560774271998186, 1.6620650573336924, -0.22045194856840114, 0.21037981611147646, 0.49709558352439615, -0.10409603034814965, -0.09880701944523407, 0.26480562809741093, -1.4261302694549518, 1.4537959152224726, 0.5108430306256783, 1.299250541011856, 0.0475278107639221, -0.26717699831176317, 0.3908459662262021, 0.14987849222043487, 0.20005005055345992, 0.7618314538439914, -0.7802067619256016, 2.064688275827374, 1.4149810574831825, 1.7973731664050858, -0.20611104063004482, -0.21491110357885448, 0.33922975506614167, 0.1673424085913585, -0.24857418327493916, 0.2857090558331392, -1.0704178424998236, 1.5169613678580962, 1.8407194323284712, 1.850031773183727, 0.07892131497804973, -0.0358865475826536, 0.6379454009825439, -0.047344415089136296, -0.22651979799994343, -0.1400130100113271, -0.6604615977127795, -0.38683987562434, -0.8676234438637848, -0.19505807444956338, -0.21188001136115753, -0.03276070424483605, -0.3777829292492889, -0.060769814977505644, -0.24690029113220854, 0.06847347530131195, 0.24860862955093785, -0.10561634091846638, -0.17015440414520872, -0.1277217262654917, 0.10503944772898603, 0.05814293706800322, -0.21516411172797842, -0.14777638298611437, 0.18630925096150663, 0.2760636961942647, -0.5385579205523742, 1.3536510386055756, 1.0318257365315597, 0.8865408018208142, -0.25940188317151447, 0.04205174709980088, 0.5072287365990714, -0.19551936075974374, 0.2627628569862242, -0.0673480508745694, 0.4372054230942421, 0.3012719171894118, -0.24150253951997452, -0.11070427264312628, -0.14421327858384675, -0.17189531026309718, -0.21937091978074424, 0.13586848003957241, 0.18502107981227509, -0.13003916728473594, -0.2673545424347945, -0.07543845291524598, -0.26223276125475736, 0.018370508943936048, -0.16558197712957975, -0.040241102528469665, -0.2242974995406943, 0.17444259901684653, 0.010682237847552147, -0.012335352147080487, -0.12846473304334152, 0.12197998142115758, -0.24895931700116605, 0.07180902691874208, -0.035021176844435446, -0.021591348772350562, 0.0322015193657231, 0.4937291751656064, 0.9511410382077623, -0.7859512547294287, 0.6670980450912607, -0.8182182709540544, -0.6329516157021101, -0.33330859843030675, -0.5296357832091932, 0.14124085368057065, -0.2186808309508446, -0.5995141053060381, 0.3216546304315201, -1.4155409804104382, 0.004139480400482347, -1.1736831859715633, -0.7917577195684166, -0.7750400891827434, -0.4646406180167782, -0.005817478828920404, -0.054717182117896106, 2.4451328139366098, 2.2894598561932074, 1.1349078624127606, 2.4001251336816036, -0.5671516935317786, -0.17250480291791762, 1.2579347855627911, -0.4698580736093125, 0.17112061958002964, 0.23854749475934298, 3.3770630227725715]
#
# =================================
#
#
# =================================
# Calibration terminated.
# =================================
#
# loss = 0.20783722970539706
# tol  = 0.001
# Optimal NN parameters = [2.6822995333924746, 0.7309544229240039, -0.5590266114346084, -0.31244729805541493, -0.3853654112507896, 0.000833568797212124, -0.034260581500892034, -0.47657376952853875, -0.02748499999324846, -0.0363264975209832, -0.23159815175935428, 0.4511230593853443, 1.4678518605809232, 1.2432124861797869, -0.11014312120809225, -0.0833781009021522, -1.435899237820142, 3.2289515343956428, -0.8161398746274009, -2.347279241738609, 2.8787706791677325, -0.5199992206562976, -1.3176010793641548, 1.0941457447121263, 0.014849414740581301, -0.1887962326658697, -0.1518545778441983, -0.42793734664512967, -0.03721650273257845, -0.478910090126866, 0.09394586980981329, -0.6158032849514616, 0.3246091269158366, -0.2281548045343399, -0.2470463876272573, 0.8726302627637851, -1.181379673089081, 1.95810805479316, 1.8560774271998186, 1.6620650573336924, -0.22045194856840114, 0.21037981611147646, 0.49709558352439615, -0.10409603034814965, -0.09880701944523407, 0.26480562809741093, -1.4261302694549518, 1.4537959152224726, 0.5108430306256783, 1.299250541011856, 0.0475278107639221, -0.26717699831176317, 0.3908459662262021, 0.14987849222043487, 0.20005005055345992, 0.7618314538439914, -0.7802067619256016, 2.064688275827374, 1.4149810574831825, 1.7973731664050858, -0.20611104063004482, -0.21491110357885448, 0.33922975506614167, 0.1673424085913585, -0.24857418327493916, 0.2857090558331392, -1.0704178424998236, 1.5169613678580962, 1.8407194323284712, 1.850031773183727, 0.07892131497804973, -0.0358865475826536, 0.6379454009825439, -0.047344415089136296, -0.22651979799994343, -0.1400130100113271, -0.6604615977127795, -0.38683987562434, -0.8676234438637848, -0.19505807444956338, -0.21188001136115753, -0.03276070424483605, -0.3777829292492889, -0.060769814977505644, -0.24690029113220854, 0.06847347530131195, 0.24860862955093785, -0.10561634091846638, -0.17015440414520872, -0.1277217262654917, 0.10503944772898603, 0.05814293706800322, -0.21516411172797842, -0.14777638298611437, 0.18630925096150663, 0.2760636961942647, -0.5385579205523742, 1.3536510386055756, 1.0318257365315597, 0.8865408018208142, -0.25940188317151447, 0.04205174709980088, 0.5072287365990714, -0.19551936075974374, 0.2627628569862242, -0.0673480508745694, 0.4372054230942421, 0.3012719171894118, -0.24150253951997452, -0.11070427264312628, -0.14421327858384675, -0.17189531026309718, -0.21937091978074424, 0.13586848003957241, 0.18502107981227509, -0.13003916728473594, -0.2673545424347945, -0.07543845291524598, -0.26223276125475736, 0.018370508943936048, -0.16558197712957975, -0.040241102528469665, -0.2242974995406943, 0.17444259901684653, 0.010682237847552147, -0.012335352147080487, -0.12846473304334152, 0.12197998142115758, -0.24895931700116605, 0.07180902691874208, -0.035021176844435446, -0.021591348772350562, 0.0322015193657231, 0.4937291751656064, 0.9511410382077623, -0.7859512547294287, 0.6670980450912607, -0.8182182709540544, -0.6329516157021101, -0.33330859843030675, -0.5296357832091932, 0.14124085368057065, -0.2186808309508446, -0.5995141053060381, 0.3216546304315201, -1.4155409804104382, 0.004139480400482347, -1.1736831859715633, -0.7917577195684166, -0.7750400891827434, -0.4646406180167782, -0.005817478828920404, -0.054717182117896106, 2.4451328139366098, 2.2894598561932074, 1.1349078624127606, 2.4001251336816036, -0.5671516935317786, -0.17250480291791762, 1.2579347855627911, -0.4698580736093125, 0.17112061958002964, 0.23854749475934298, 3.3770630227725715]
#
# ==============================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 opt_params = pb.calibrate(Data=Data, **config)
#
# File ~/miniconda3/envs/KeithProject/lib/python3.9/site-packages/fracturbulence/Calibration.py:280, in CalibrationProblem.calibrate(self, **kwargs)
#     278 print('tol  = {0}'.format(tol))
#     279 self.print_parameters()
# --> 280 self.plot(plt_dynamic=False)
#     282 return self.parameters
#
# File ~/miniconda3/envs/KeithProject/lib/python3.9/site-packages/fracturbulence/Calibration.py:429, in CalibrationProblem.plot(self, **kwargs)
#     427 else:
#     428     print("="*30)
# --> 429     print("SAVING FINAL SOLUTION RESULTS TO " + f'{self.output_directory+"final_solution.png"}')
#     430     self.fig.savefig(self.output_directory+"final_solution.png", format='png', dpi=100)
#     431     #self.fig.savefig(self.output_directory+'Final_solution.png',format='png',dpi=100)
#
# TypeError: unsupported operand type(s) for +: 'PosixPath' and 'str'

# %%
X = [1, 2, 3, 4]

# %%
plt.plot(X)

# %%
plt.savefig(savedir)
